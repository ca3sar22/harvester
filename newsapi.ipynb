# %%
from newsapi import NewsApiClient
import datetime as dt
import pandas as pd

# %%
newsapi = NewsApiClient(api_key="52e22219a99b493298aa873d855fe6d9")

# %%
keyword = input("Enter your keyword: ")
# Out:
# Enter your keyword: climate

# %%
data = newsapi.get_everything(q=keyword, language="en", page_size=100)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
data['status']
# Out:
# 'ok'

# %%
data['totalResults']
# Out:
# 29558

# %%
data['articles'][0]
# Out:
# {'source': {'id': 'the-verge', 'name': 'The Verge'},
#  'author': 'Justine Calma',
#  'title': 'The climate controversy swirling around NFTs',
#  'description': 'Most NFTs are bought and sold with Ethereum, a cryptocurrency that guzzles up energy and pumps out a lot of greenhouse gas emissions. Artists are fighting over whether there can be a more sustainable future for crypto art.',
#  'url': 'https://www.theverge.com/2021/3/15/22328203/nft-cryptoart-ethereum-blockchain-climate-change',
#  'urlToImage': 'https://cdn.vox-cdn.com/thumbor/pYrvxU6TUFVYkAwb6h1U4BPYMj0=/0x431:6000x3572/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22366636/1230723200.jpg',
#  'publishedAt': '2021-03-15T13:51:11Z',
#  'content': 'Famed auction house Christies just sold its first purely digital piece of art for a whopping $69 million. For that price, the buyer got a digital file of a collage of 5,000 images and a complex legac… [+12891 chars]'}

# %%
data
# Out:
# {'status': 'ok',
#  'totalResults': 29558,
#  'articles': [{'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Justine Calma',
#    'title': 'The climate controversy swirling around NFTs',
#    'description': 'Most NFTs are bought and sold with Ethereum, a cryptocurrency that guzzles up energy and pumps out a lot of greenhouse gas emissions. Artists are fighting over whether there can be a more sustainable future for crypto art.',
#    'url': 'https://www.theverge.com/2021/3/15/22328203/nft-cryptoart-ethereum-blockchain-climate-change',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/pYrvxU6TUFVYkAwb6h1U4BPYMj0=/0x431:6000x3572/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22366636/1230723200.jpg',
#    'publishedAt': '2021-03-15T13:51:11Z',
# ...

# %%
articles = data['articles']

# %%
df = pd.DataFrame(articles)

# %%
df.head(10)
# Out:
#                                        source  \
# 0    {'id': 'the-verge', 'name': 'The Verge'}
# 1            {'id': 'wired', 'name': 'Wired'}
# 2            {'id': 'wired', 'name': 'Wired'}
# 3      {'id': 'mashable', 'name': 'Mashable'}
# 4  {'id': 'techcrunch', 'name': 'TechCrunch'}
# 5  {'id': 'techcrunch', 'name': 'TechCrunch'}
# 6      {'id': 'engadget', 'name': 'Engadget'}
# 7      {'id': None, 'name': 'Lifehacker.com'}
# 8            {'id': 'wired', 'name': 'Wired'}
# 9    {'id': 'the-verge', 'name': 'The Verge'}
#
#                                               author  \
# 0                                      Justine Calma
# 1                                        Steven Levy
# 2                                       Tim O'Reilly
# 3                                       Mark Kaufman
# 4                                   Jonathan Shieber
# 5                                   Jonathan Shieber
# 6  https://www.engadget.com/about/editors/andrew-...
# ...

# %%
df.shape
# Out:
# (20, 8)

# %%
sources=[]
for source in df['source']:
        sources.append(source['id'])

# %%
sources
# Out:
# ['the-verge',
#  'wired',
#  'wired',
#  'mashable',
#  'techcrunch',
#  'techcrunch',
#  'engadget',
#  None,
#  'wired',
#  'the-verge',
#  'techcrunch',
#  'mashable',
#  'bbc-news',
#  'wired',
#  'the-verge',
#  None,
#  'techcrunch',
#  'techcrunch',
#  'techcrunch',
#  'techcrunch']

# %%
df['source']=sources

# %%
df.head()
# Out:
#        source            author  \
# 0   the-verge     Justine Calma
# 1       wired       Steven Levy
# 2       wired      Tim O'Reilly
# 3    mashable      Mark Kaufman
# 4  techcrunch  Jonathan Shieber
#
#                                                title  \
# 0       The climate controversy swirling around NFTs
# 1  Bill Gates Is Upbeat on Climate, Capitalism, a...
# 2  Climate Change Will Reshape Silicon Valley As ...
# 3  The EPA's climate webpage got axed. Now it's b...
# 4  The Department of Defense is establishing a wo...
#
#                                          description  \
# 0  Most NFTs are bought and sold with Ethereum, a...
# 1  The technologist and philanthropist goes beyon...
# 2  The next entrepreneurial revolution will arise...
# 3  The Trump administration deleted the U.S. Envi...
# 4  The U.S. Department of Defense is setting up a...
#
#                                                  url  \
# 0  https://www.theverge.com/2021/3/15/22328203/nf...
# ...

# %%
df.to_csv('C:/Users/Goldy/OneDrive/Desktop/datasets/news2.csv',index=False)

# %%
test = pd.read_csv('C:/Users/Goldy/OneDrive/Desktop/datasets/news.csv')

# %%
test.head()
# Out:
#                         author  \
# 0                     ABC News
# 1  Jesse Thompson, Kate Ashton
# 2   Daniel Smith, Kelsie Iorio
# 3               Felicity James
# 4                     ABC News
#
#                                                title  \
# 0  Japan wins fifth straight Asia World Cup Group...
# 1  Push to close Kakadu's Gunlom Falls site as Pa...
# 2  COVID live updates: New Queensland coronavirus...
# 3  Santos and partners investing $4.7 billion to ...
# 4  Child unknowingly tweets from US nuclear comma...
#
#                                          description  \
# 0  The Socceroos' traditional continental rivals ...
# 1  A powerful land council is urged to call a spe...
# 2  At least a dozen new COVID-exposed locations h...
# 3  Energy giant Santos will pour $4.7 billion int...
# 4  Is "l;;gmlxzssaw" a US nuclear launch code? Is...
#
#                                                  url  \
# 0  http://www.abc.net.au/news/2021-03-31/japan-ro...
# ...
